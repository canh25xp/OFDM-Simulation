# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft, ifft
from numpy import pi as PI
from numpy import sin, cos, exp

# %%
x = np.array([0, 1-1j, 1+1j, 0,0,0,1-1j, -1-1j])

# %%
y = ifft(x, 8)

# %%
y
# Out:
# array([ 0.25-0.25j      , -0.25+0.j        , -0.25+0.25j      ,
#         0.25+0.35355339j,  0.25+0.25j      , -0.25+0.j        ,
#        -0.25-0.25j      ,  0.25-0.35355339j])

# %%
N = 600 # Number of samplepoints
T = 1.0 / 800.0 # sample spacing
x = np.linspace(0.0, N*T, N)
y = sin(50.0 * 2.0*PI*x) + 0.5*sin(100 * 2.0*PI*x)
# y = np.array([1, 0, 0.1+0.1j])
plt.figure(figsize=(20,5))
plt.plot(x,y)
plt.show()

# %%
yf = fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)
plt.plot(xf, 2.0/N * np.abs(yf[:N//2]))
plt.xlim(0,N//2)
plt.ylim(0,1)
plt.grid(True)
plt.show()

# %%
N = 1000 # Number of samplepoints
t = np.linspace(0, 2*PI, N, endpoint=True)
f = 3.0 # Frequency in Hz
A = 100.0 # Amplitude in Unit
y = A * np.sin(2*PI*f*t) # Signal

# %%
plt.plot(t,y)
plt.xlabel('Time ($s$)')
plt.ylabel('Amplitude ($Unit$)')
plt.show()

# %%
yf = fft(y)
plt.plot(abs(yf))
